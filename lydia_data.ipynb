# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
json_file = "https://data.cdc.gov/resource/n8mc-b4w4.json"
covid_df = pd.read_json(json_file)
covid_df.head()
# Out:
#   case_month res_state  state_fips_code res_county county_fips_code  \
# 0    2020-12        MN               27      DODGE            27039
# 1    2020-11        MI               26    GLADWIN            26051
# 2    2021-04        VT               50    ORLEANS            50019
# 3    2020-11        AL                1  LIMESTONE            01083
# 4    2021-01        NY               36  SCHOHARIE            36095
#
#         age_group     sex     race ethnicity  case_positive_specimen  \
# 0  18 to 49 years      NA       NA        NA                    -1.0
# 1  18 to 49 years      NA       NA        NA                     NaN
# 2  18 to 49 years      NA       NA        NA                     0.0
# 3    0 - 17 years  Female  Missing   Missing                     NaN
# 4    0 - 17 years  Female       NA        NA                     0.0
#
#    case_onset_interval   process exposure_yn             current_status  \
# 0                  0.0   Missing     Missing  Laboratory-confirmed case
# 1                  NaN   Missing     Missing  Laboratory-confirmed case
# 2                  0.0  Multiple         Yes  Laboratory-confirmed case
# 3                  NaN   Missing     Missing  Laboratory-confirmed case
# 4                  NaN   Missing     Missing  Laboratory-confirmed case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0    Symptomatic  Missing  Missing       No                      NaN
# 1        Missing  Missing  Missing  Unknown                      NaN
# 2    Symptomatic       No  Missing       NA                      Yes
# 3        Missing  Missing  Missing  Missing                      NaN
# 4        Missing  Missing  Missing       No                      NaN

# %%
json_file = "https://data.cdc.gov/resource/b7pe-5nws.json"
moderna_df = pd.read_json(json_file)
moderna_df.head()
# Out:
#     jurisdiction      week_of_allocations  _1st_dose_allocations  \
# 0    Connecticut  2021-06-21T00:00:00.000                  41220
# 1          Maine  2021-06-21T00:00:00.000                  15800
# 2  Massachusetts  2021-06-21T00:00:00.000                  79500
# 3  New Hampshire  2021-06-21T00:00:00.000                  15800
# 4   Rhode Island  2021-06-21T00:00:00.000                  12480
#
#    _2nd_dose_allocations
# 0                  41220
# 1                  15800
# 2                  79500
# 3                  15800
# 4                  12480

# %%
json_file = "https://data.cdc.gov/resource/b7pe-5nws.json"
pfizer_df = pd.read_json(json_file)
pfizer_df.head()
# Out:
#     jurisdiction      week_of_allocations  _1st_dose_allocations  \
# 0    Connecticut  2021-06-21T00:00:00.000                  41220
# 1          Maine  2021-06-21T00:00:00.000                  15800
# 2  Massachusetts  2021-06-21T00:00:00.000                  79500
# 3  New Hampshire  2021-06-21T00:00:00.000                  15800
# 4   Rhode Island  2021-06-21T00:00:00.000                  12480
#
#    _2nd_dose_allocations
# 0                  41220
# 1                  15800
# 2                  79500
# 3                  15800
# 4                  12480

# %%
json_file = "https://data.cdc.gov/resource/hk9y-quqm.json"
pfizer_df = pd.read_json(json_file)
pfizer_df.head()
# Out:
#                 data_as_of               start_date                 end_date  \
# 0  2021-08-01T00:00:00.000  2020-01-01T00:00:00.000  2021-07-31T00:00:00.000
# 1  2021-08-01T00:00:00.000  2020-01-01T00:00:00.000  2021-07-31T00:00:00.000
# 2  2021-08-01T00:00:00.000  2020-01-01T00:00:00.000  2021-07-31T00:00:00.000
# 3  2021-08-01T00:00:00.000  2020-01-01T00:00:00.000  2021-07-31T00:00:00.000
# 4  2021-08-01T00:00:00.000  2020-01-01T00:00:00.000  2021-07-31T00:00:00.000
#
#       group          state       condition_group                condition  \
# 0  By Total  United States  Respiratory diseases  Influenza and pneumonia
# 1  By Total  United States  Respiratory diseases  Influenza and pneumonia
# 2  By Total  United States  Respiratory diseases  Influenza and pneumonia
# 3  By Total  United States  Respiratory diseases  Influenza and pneumonia
# 4  By Total  United States  Respiratory diseases  Influenza and pneumonia
#
#   icd10_codes age_group  covid_19_deaths  number_of_mentions flag
# 0     J09-J18      0-24            450.0               469.0  NaN
# 1     J09-J18     25-34           2027.0              2081.0  NaN
# 2     J09-J18     35-44           5408.0              5558.0  NaN
# 3     J09-J18     45-54          15899.0             16376.0  NaN
# 4     J09-J18     55-64          39759.0             40878.0  NaN

# %%
csv_file = "population.csv"
population_df = pd.read_csv(csv_file)
population_df.head()
# Out:
#    rank         State       Pop  Growth   Pop2018   Pop2010  growthSince2010  \
# 0     1    California  39613493  0.0038  39461588  37319502           0.0615
# 1     2         Texas  29730311  0.0385  28628666  25241971           0.1778
# 2     3       Florida  21944577  0.0330  21244317  18845537           0.1644
# 3     4      New York  19299981 -0.0118  19530351  19399878          -0.0051
# 4     5  Pennsylvania  12804123  0.0003  12800922  12711160           0.0073
#
#    Percent   density
# 0   0.1184  254.2929
# 1   0.0889  113.8081
# 2   0.0656  409.2229
# 3   0.0577  409.5400
# 4   0.0383  286.1704

# %%
json_file = "data.json"
states_df = pd.read_json(json_file)
states_df.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA
